# %%
import numpy as np

# %%
import cv2 as cv

# %% [markdown]
# MAKING A BLANK MATRIX OF (300,500)

# %%
blank=np.zeros((300,500),dtype='uint8')

# %% [markdown]
# DEFINING ORIGINS OF ALL 15 CIRCLES

# %%
org11=(2+41,30)
org12=(2+41+82,30)
org13=(2+41+82*2,30)


org21=(2+41,30+60)
org22=(43+82,30+60)
org23=(43+82*2,30+60)

org31=(2+41,30+60*2)
org32=(43+82,30+60*2)
org33=(43+82*2,30+60*2)

org41=(2+41,30+60*3)
org42=(43+82,30+60*3)
org43=(43+82*2,30+60*3)

org51=(2+41,30+60*4)
org52=(43+82,30+60*4)
org53=(43+82*2,30+60*4)

# %% [markdown]
# FUNCTIONS FOR EVERY DIGIT

# %%
from google.colab.patches import cv2_imshow
from google.colab import output

# %%
def one(blank,org):
    cv.circle(blank,(org21[0]+org[0],org21[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org12[0]+org[0],org12[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org22[0]+org[0],org22[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org32[0]+org[0],org32[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org42[0]+org[0],org42[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org52[0]+org[0],org52[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org51[0]+org[0],org51[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org53[0]+org[0],org53[1]),25,(255,255,255),thickness=-1)
    cv2_imshow(blank)
    

def two(blank,org):
    cv.circle(blank,(org11[0]+org[0],org11[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org12[0]+org[0],org12[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org13[0]+org[0],org13[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org23[0]+org[0],org23[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org33[0]+org[0],org33[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org32[0]+org[0],org32[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org31[0]+org[0],org31[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org41[0]+org[0],org41[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org51[0]+org[0],org51[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org52[0]+org[0],org52[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org53[0]+org[0],org53[1]),25,(255,255,255),thickness=-1)
    cv2_imshow(blank)

def three(blank,org):
    cv.circle(blank,(org11[0]+org[0],org11[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org12[0]+org[0],org12[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org13[0]+org[0],org13[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org23[0]+org[0],org23[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org33[0]+org[0],org33[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org32[0]+org[0],org32[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org31[0]+org[0],org31[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org43[0]+org[0],org43[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org51[0]+org[0],org51[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org52[0]+org[0],org52[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org53[0]+org[0],org53[1]),25,(255,255,255),thickness=-1)
    cv2_imshow(blank)

def four(blank,org):
    cv.circle(blank,(org11[0]+org[0],org11[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org21[0]+org[0],org21[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org31[0]+org[0],org31[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org32[0]+org[0],org32[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org33[0]+org[0],org33[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org23[0]+org[0],org23[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org13[0]+org[0],org13[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org43[0]+org[0],org43[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org53[0]+org[0],org53[1]),25,(255,255,255),thickness=-1)
    cv2_imshow(blank)

def five(blank,org):
    cv.circle(blank,(org11[0]+org[0],org11[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org12[0]+org[0],org12[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org13[0]+org[0],org13[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org21[0]+org[0],org21[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org31[0]+org[0],org31[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org32[0]+org[0],org32[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org33[0]+org[0],org33[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org43[0]+org[0],org43[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org51[0]+org[0],org51[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org52[0]+org[0],org52[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org53[0]+org[0],org53[1]),25,(255,255,255),thickness=-1)
    cv2_imshow(blank)

def six(blank,org): 
    cv.circle(blank,(org11[0]+org[0],org11[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org12[0]+org[0],org12[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org13[0]+org[0],org13[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org21[0]+org[0],org21[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org31[0]+org[0],org31[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org32[0]+org[0],org32[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org33[0]+org[0],org33[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org43[0]+org[0],org43[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org51[0]+org[0],org51[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org52[0]+org[0],org52[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org53[0]+org[0],org53[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org41[0]+org[0],org41[1]),25,(255,255,255),thickness=-1)
    cv2_imshow(blank)

def seven(blank,org):
    cv.circle(blank,(org11[0]+org[0],org11[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org12[0]+org[0],org12[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org13[0]+org[0],org13[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org23[0]+org[0],org23[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org33[0]+org[0],org33[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org43[0]+org[0],org43[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org53[0]+org[0],org53[1]),25,(255,255,255),thickness=-1)
    cv2_imshow(blank)

def eight(blank,org):
    cv.circle(blank,(org11[0]+org[0],org11[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org12[0]+org[0],org12[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org13[0]+org[0],org13[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org23[0]+org[0],org23[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org33[0]+org[0],org33[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org32[0]+org[0],org32[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org31[0]+org[0],org31[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org43[0]+org[0],org43[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org51[0]+org[0],org51[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org52[0]+org[0],org52[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org53[0]+org[0],org53[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org21[0]+org[0],org21[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org41[0]+org[0],org41[1]),25,(255,255,255),thickness=-1)
    cv2_imshow(blank)

def nine(blank,org):
    cv.circle(blank,(org11[0]+org[0],org11[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org12[0]+org[0],org12[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org13[0]+org[0],org13[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org23[0]+org[0],org23[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org33[0]+org[0],org33[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org32[0]+org[0],org32[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org31[0]+org[0],org31[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org43[0]+org[0],org43[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org51[0]+org[0],org51[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org52[0]+org[0],org52[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org53[0]+org[0],org53[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org21[0]+org[0],org21[1]),25,(255,255,255),thickness=-1)
    cv2_imshow(blank)

def zero(blank,org):
    cv.circle(blank,(org11[0]+org[0],org11[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org12[0]+org[0],org12[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org13[0]+org[0],org13[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org23[0]+org[0],org23[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org33[0]+org[0],org33[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org31[0]+org[0],org31[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org43[0]+org[0],org43[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org51[0]+org[0],org51[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org52[0]+org[0],org52[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org53[0]+org[0],org53[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org21[0]+org[0],org21[1]),25,(255,255,255),thickness=-1)
    cv.circle(blank,(org41[0]+org[0],org41[1]),25,(255,255,255),thickness=-1)
    cv2_imshow(blank)

roll_no=int((input("ENTER YOUR ROLL NO:")))


a=int(((roll_no)%100-(roll_no)%10)/10)
b=int((roll_no)%10)


if(a==0):
    zero(blank,(0,0))

elif(a==1):
    one(blank,(0,0))

elif(a==2):
    two(blank,(0,0))

elif(a==3):
    three(blank,(0,0))

elif(a==4):
    four(blank,(0,0))

elif(a==5):
    five(blank,(0,0))

elif(a==6):
    six(blank,(0,0))

elif(a==7):
    seven(blank,(0,0))

elif(a==8):
    eight(blank,(0,0)) 

elif(a==9):
    nine(blank,(0,0)) 

output.clear()

if(b==0):
    zero(blank,(250,0))

elif(b==1):
    one(blank,(250,0))

elif(b==2):
    two(blank,(250,0))

elif(b==3):
    three(blank,(250,0))

elif(b==4):
    four(blank,(250,0))

elif(b==5):
    five(blank,(250,0))

elif(b==6):
    six(blank,(250,0))

elif(b==7):
    seven(blank,(250,0))

elif(b==8):
    eight(blank,(250,0)) 

elif(b==9):
    nine(blank,(250,0)) 

cv.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=500x300 at 0x7FAB948DAB60>
# -1
